# %% [markdown]
# <a href="https://colab.research.google.com/github/dschloe/inflern_ml/blob/main/pandas_style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame(np.random.randn(8, 4), columns=list('ABCD'))
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_acff9_row0_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_acff9_row0_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_acff9_row0_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_acff9_row0_col3, #T_acff9_row1_col1, #T_acff9_row2_col0, #T_acff9_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_acff9_row1_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_acff9_row1_col2 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_acff9_row1_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_acff9_row2_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_acff9_row2_col2 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_acff9_row2_col3, #T_acff9_row4_col0, #T_acff9_row5_col2, #T_acff9_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_acff9_row3_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# ...
